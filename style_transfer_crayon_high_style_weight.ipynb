# %% [markdown]
# # Neural Style Transfer in TensorFlow2 (High Style Weight)
# This code is slightly modified from TensorFlow's official tutorial (https://www.tensorflow.org/tutorials/generative/style_transfer), which implements
# `A Neural Algorithm of Artistic Style` (Gatys et al.) (https://arxiv.org/abs/1508.06576)

# %%
import tensorflow as tf
from model import *

# %% [markdown]
# ## Load Images

# %%
# Load images
content_image = load_img('img/napoleon_on_tsunami.jpg', dim=800)
style_image = load_img('img/kaiju_rotate.jpg', dim=800)

# %%
# Content
tensor_to_image(content_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x557 at 0x7FDEF010EC18>

# %%
# Style
tensor_to_image(style_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x524 at 0x7FDE701149E8>

# %% [markdown]
# ## Load Model

# %%
# Content layer for feature maps
content_layers = ['block5_conv2']  

# Style layer of interest
style_layers = ['block1_conv1',
                'block2_conv1',
                'block3_conv1', 
                'block4_conv1', 
                'block5_conv1']

num_content_layers = len(content_layers)
num_style_layers = len(style_layers)

# Model that returns the style and content tensors
extractor = StyleContentModel(style_layers, content_layers)
style_targets = extractor(style_image)['style']
content_targets = extractor(content_image)['content']

# Convert content image to tensor
image = tf.Variable(content_image)

# %% [markdown]
# ## Train

# %%
# Weights
style_weight = 1e1
content_weight = 1e4

lr = 0.02
# Optimizer (LBFGS is not available in TF2.0)
opt = tf.optimizers.Adam(learning_rate=lr, beta_1=0.99, epsilon=1e-1)

# Decrease high frequency artifacts (regularization)
total_variation_weight = 30

epochs = 30
steps_per_epoch = 100

# Image name for saving
img_name = "img/surfing_napoleon_crayon_style"

new_image = train_model(epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            save_image=True,
            img_name=img_name,
            display_image=True,
            image=image,
            style_weight=style_weight,
            content_weight=content_weight,
            num_style_layers=num_style_layers,
            num_content_layers=num_content_layers,
            style_targets=style_targets,
            content_targets=content_targets,
            extractor=extractor,
            opt=opt,
            total_variation_weight=total_variation_weight)
# Out:
# <PIL.Image.Image image mode=RGB size=800x557 at 0x7FDE14616470>
# Train step: 3000
